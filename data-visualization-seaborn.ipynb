# %% [markdown]
# **Importing Libraries and Dataset**

# %%
#import pandas as pd
#import seaborn as sns
#import matplotlib.pyplot as plt
#pd.set_option('display.max_columns', None)
#pd.set_option('display.width', 500)

#df = sns.load_dataset("tips")
#df.head()

# %% [markdown]
# **Visualization with Seaborn countplot**

# %%
#df["sex"].value_counts()
#sns.countplot(x=df["sex"], data=df)
#plt.show()

# %% [markdown]
# ![Ekran Resmi 2024-09-01 21.26.15.png](attachment:3d5b7b35-709e-4f85-92ac-3b8b1a188cc8.png)

# %% [markdown]
# **Visualization with Seaborn boxplot**

# %%
#sns.boxplot(x=df["total_bill"])
#plt.show()

# %% [markdown]
# ![Ekran Resmi 2024-09-01 21.28.11.png](attachment:50a43b52-8a72-41bb-9375-e77e9765ac08.png)

# %% [markdown]
# **Visualization with Pandas hist**

# %%
#df["total_bill"].hist()
#plt.show()

# %% [markdown]
# ![Ekran Resmi 2024-09-01 21.29.03.png](attachment:a375c261-c84d-40c0-849c-ed3554306b02.png)
